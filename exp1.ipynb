# %% [markdown]
# <a href="https://colab.research.google.com/github/sampada-11/Data_Science_Lab/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Multiplication Table**

# %%
#multiplication table
def display_multiplication_table(number):
    print(f"Multiplication Table for {number}:")
    for i in range(1, 11):  # Table from 1 to 10
        print(f"{number} x {i} = {number * i}")

# Example usage:
while True:
    try:
        user_input = input("Enter an integer to display its multiplication table (or 'quit' to exit): ")
        if user_input.lower() == 'quit':
            break
        num = int(user_input)
        display_multiplication_table(num)
        print("\n") # Add a newline for better readability
    except ValueError:
        print("Invalid input. Please enter an integer or 'quit'.")
# Out:
# Enter an integer to display its multiplication table (or 'quit' to exit): 5
# Multiplication Table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
#
# Enter an integer to display its multiplication table (or 'quit' to exit): quit

# %% [markdown]
# **Check Palindrome**

# %%
#palindrome
def is_palindrome(number):
    # Convert the number to a string to easily reverse it
    num_str = str(number)
    # Compare the original string with its reverse
    if num_str == num_str[::-1]:
        return f"{number} is a palindrome."
    else:
        return f"{number} is not a palindrome."

# Example usage:
while True:
    try:
        user_input = input("Enter an integer to check if it's a palindrome (or 'quit' to exit): ")
        if user_input.lower() == 'quit':
            break
        number = int(user_input)
        print(is_palindrome(number))
    except ValueError:
        print("Invalid input. Please enter an integer or 'quit'.")
# Out:
# Enter an integer to check if it's a palindrome (or 'quit' to exit): madam
# Invalid input. Please enter an integer or 'quit'.
# Enter an integer to check if it's a palindrome (or 'quit' to exit): 1254521
# 1254521 is a palindrome.
# Enter an integer to check if it's a palindrome (or 'quit' to exit): 1235226
# 1235226 is not a palindrome.
# Enter an integer to check if it's a palindrome (or 'quit' to exit): quit

# %% [markdown]
# **Even Odd**

# %%
def check_odd_even(number):
    if number % 2 == 0:
        return f"{number} is an even number."
    else:
        return f"{number} is an odd number."

# Example usage:
while True:
    try:
        user_input = input("Enter an integer to check if it's odd or even (or 'quit' to exit): ")
        if user_input.lower() == 'quit':
            break
        number = int(user_input)
        print(check_odd_even(number))
    except ValueError:
        print("Invalid input. Please enter an integer or 'quit'.")
# Out:
# Enter an integer to check if it's odd or even (or 'quit' to exit): 55
# 55 is an odd number.
# Enter an integer to check if it's odd or even (or 'quit' to exit): 44
# 44 is an even number.
# Enter an integer to check if it's odd or even (or 'quit' to exit): quit

# %% [markdown]
# **Factorial**

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Example usage:
while True:
    try:
        user_input = input("Enter a non-negative integer to calculate its factorial (or 'quit' to exit): ")
        if user_input.lower() == 'quit':
            break
        number = int(user_input)
        print(f"The factorial of {number} is {factorial(number)}")
    except ValueError:
        print("Invalid input. Please enter a non-negative integer or 'quit'.")
# Out:
# Enter a non-negative integer to calculate its factorial (or 'quit' to exit): 5
# The factorial of 5 is 120
# Enter a non-negative integer to calculate its factorial (or 'quit' to exit): 6
# The factorial of 6 is 720
# Enter a non-negative integer to calculate its factorial (or 'quit' to exit): 4
# The factorial of 4 is 24
# Enter a non-negative integer to calculate its factorial (or 'quit' to exit): quit

# %% [markdown]
# # Task
# Test the expert system's decision-making by inputting characteristics into the user interface and observing the inferred animal.

# %% [markdown]
# ## Test Expert System User Interface
#
# ### Subtask:
# Run the interactive user interface to test the expert system's decision-making by inputting characteristics and observing the inferred animal. This will allow for direct interaction with the system.

# %% [markdown]
# ## Test Expert System User Interface
#
# ### Subtask:
# Run the interactive user interface to test the expert system's decision-making by inputting characteristics and observing the inferred animal. This will allow for direct interaction with the system.
#
# #### Instructions
# 1. Run the code cell that implements the user interface. This cell is interactive and will prompt you to 'Enter characteristics:'.
# 2. Input various sets of characteristics based on the `knowledge_base` defined earlier to test the system's ability to identify animals. For example, try:
#    - `has fur, barks, is domesticated` (should infer 'Dog')
#    - `lives in water, has fins, has gills` (should infer 'Fish')
#    - `has feathers, can fly, lays eggs` (should infer 'Bird')
#    - `has rough skin, has four legs, lives in water and land` (should infer 'Frog')
# 3. Test the system with characteristics that don't match any defined rules. For example, try:
#    - `has scales, can fly, likes bananas` (should infer 'Unknown animal')
#    - `has blue skin, flies, sings` (should infer 'Unknown animal')
# 4. Observe the inferred animal or the 'Unknown animal' message returned by the system for each input.
# 5. To exit the interactive interface, type `quit` and press Enter.

# %% [markdown]
# ## Test Expert System User Interface
#
# ### Subtask:
# Run the interactive user interface to test the expert system's decision-making by inputting characteristics and observing the inferred animal. This will allow for direct interaction with the system.
#
# #### Instructions
# 1. Run the code cell that implements the user interface. This cell is interactive and will prompt you to 'Enter characteristics:'.
# 2. Input various sets of characteristics based on the `knowledge_base` defined earlier to test the system's ability to identify animals. For example, try:
#    - `has fur, barks, is domesticated` (should infer 'Dog')
#    - `lives in water, has fins, has gills` (should infer 'Fish')
#    - `has feathers, can fly, lays eggs` (should infer 'Bird')
#    - `has rough skin, has four legs, lives in water and land` (should infer 'Frog')
# 3. Test the system with characteristics that don't match any defined rules. For example, try:
#    - `has scales, can fly, likes bananas` (should infer 'Unknown animal')
#    - `has blue skin, flies, sings` (should infer 'Unknown animal')
# 4. Observe the inferred animal or the 'Unknown animal' message returned by the system for each input.
# 5. To exit the interactive interface, type `quit` and press Enter.

# %% [markdown]
# ## Summarize Expert System Capabilities
#
# ### Subtask:
# Provide a summary of the expert system, including its knowledge base structure, inference mechanism, and user interaction, based on the developed components and the testing conducted.

# %% [markdown]
# ## Summarize Expert System Capabilities
#
# ### Subtask:
# Provide a summary of the expert system, including its knowledge base structure, inference mechanism, and user interaction, based on the developed components and the testing conducted.
#
# ### Summary of Expert System Capabilities
#
# **1. Knowledge Base Structure:**
# The expert system's knowledge base is structured as a Python list of dictionaries. Each dictionary represents a rule for identifying an animal. A rule consists of two key components:
# *   `'conditions'`: A list of strings, where each string is a characteristic that must be present for the rule to be true (e.g., `['has fur', 'barks', 'is domesticated']`).
# *   `'conclusion'`: A string representing the animal identified if all conditions are met (e.g., `'Dog'`)
#
# This structure allows for a clear and organized representation of domain-specific knowledge, in this case, for animal identification.
#
# **2. Inference Mechanism:**
# The inference engine is implemented as a Python function named `infer_animal`. It operates by taking a list of user-provided characteristics and iterating through each rule in the knowledge base. For each rule, it checks if *all* conditions specified in the rule's `'conditions'` list are present within the user's characteristics. The first rule whose conditions are fully satisfied leads to its `'conclusion'` being returned as the inferred animal. If no rules in the knowledge base have all their conditions met by the user's input, the engine concludes that the animal is "Unknown animal based on provided characteristics."
#
# **3. User Interface (UI):**
# The system features a basic text-based user interface that allows for interactive querying. Users are prompted to enter a comma-separated list of animal characteristics. The UI processes this input, converts it into a list of individual characteristics, and then passes it to the `infer_animal` function. The inferred animal (or the "Unknown" message) is then displayed back to the user. The UI also includes a loop for continuous queries and a 'quit' command to gracefully exit the system, enhancing user experience.
#
# **4. Domain of the Expert System:**
# The expert system's domain is **animal identification**. It is designed to classify animals based on a set of predefined characteristics stored in its knowledge base.
#
# **5. Overall Capabilities and Limitations:**
# *   **Capabilities:** The system effectively identifies animals for which clear rules exist in its knowledge base and for which sufficient characteristics are provided by the user. It accurately matched `Dog`, `Fish`, and `Frog` in testing when the exact conditions were met. Its forward-chaining inference mechanism is straightforward and efficient for this type of rule-based system.
# *   **Limitations:** The system is entirely dependent on the completeness and accuracy of its knowledge base. It cannot handle ambiguous inputs, partial matches (unless designed to do so, which it currently is not), or characteristics that are not explicitly part of any rule. As observed in testing, if a characteristic is misspelled or a combination of characteristics doesn't perfectly align with a defined rule, it defaults to "Unknown animal based on provided characteristics," even if some characteristics might hint at a known animal. This highlights its strictly rule-following nature and lack of fuzzy logic or learning capabilities.

# %% [markdown]
# ## Expert System for Animal Identification
#
# This expert system is designed to identify animals based on a set of provided characteristics. It consists of three main components:
#
# 1.  **Knowledge Base**: A collection of rules that define animals and their characteristics.
# 2.  **Inference Engine**: The logic that processes user input against the knowledge base to draw conclusions.
# 3.  **User Interface**: An interactive way for users to input characteristics and receive animal identifications.

# %% [markdown]
# ### 1. Knowledge Base
#
# The knowledge base is represented as a list of dictionaries, where each dictionary defines an animal and its identifying characteristics. Each rule has a `'conditions'` key (a list of characteristics) and a `'conclusion'` key (the animal's name).

# %% [markdown]
# ## Expert System for Animal Identification (Single Code Cell)
#
# This single code cell contains the complete expert system for animal identification. It includes:
#
# 1.  **Knowledge Base**: A list of rules defining animals and their characteristics.
# 2.  **Inference Engine**: A function to match user-provided characteristics against the knowledge base.
# 3.  **User Interface**: An interactive loop that prompts the user for characteristics and displays the inferred animal.
#
# To use it, run this cell and follow the prompts. Type `quit` to exit the system.

# %%
# 1. Knowledge Base: Define the knowledge base for animal identification
knowledge_base = [
    {
        'conditions': ['has fur', 'barks', 'is domesticated'],
        'conclusion': 'Dog'
    },
    {
        'conditions': ['lives in water', 'has fins', 'has gills'],
        'conclusion': 'Fish'
    },
    {
        'conditions': ['has feathers', 'can fly', 'lays eggs'],
        'conclusion': 'Bird'
    },
    {
        'conditions': ['has rough skin', 'has four legs', 'lives in water and land'],
        'conclusion': 'Frog'
    },
    {
        'conditions': ['has fur', 'meows', 'is domesticated'],
        'conclusion': 'Cat'
    },
    {
        'conditions': ['has scales', 'crawls', 'no legs'],
        'conclusion': 'Snake'
    }
]

# 2. Inference Engine: Implement the inference engine
def infer_animal(characteristics):
    for rule in knowledge_base:
        # Check if all conditions in the rule are present in the provided characteristics
        if all(condition in characteristics for condition in rule['conditions']):
            return rule['conclusion']
    return 'Unknown animal based on provided characteristics.'

# 3. User Interface: Simple interactive user interface
print("Welcome to the Animal Identification Expert System!")
print("Enter characteristics as a comma-separated list (e.g., 'has fur, barks, is domesticated').")
print("Type 'quit' to exit.")

while True:
    user_input = input("\nEnter characteristics: ")
    if user_input.lower() == 'quit':
        print("Exiting expert system. Goodbye!")
        break

    # Process user input
    # Remove leading/trailing spaces and convert to lowercase for consistent matching
    # Also remove any surrounding quotes that users might include in their input
    input_characteristics = [char.strip().lower().replace("'", "").replace('"', '') for char in user_input.split(',')]

    # Infer the animal
    inferred_animal = infer_animal(input_characteristics)
    print(f"Inferred animal: {inferred_animal}")
# Out:
# Welcome to the Animal Identification Expert System!
# Enter characteristics as a comma-separated list (e.g., 'has fur, barks, is domesticated').
# Type 'quit' to exit.
#
# Enter characteristics: has fur , barks , is domesticated
# Inferred animal: Dog
#
# Enter characteristics: has scales , crawls , no legs
# Inferred animal: Snake
#
# Enter characteristics: quit
# Exiting expert system. Goodbye!
